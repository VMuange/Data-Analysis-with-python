# %% [markdown]
# ## pivot() and pivot_table() Methods
#
# - The pivot() method reshapes data based on column values.
#   Does not support data aggregation.
#
# - pivot_table() method creates a spreadsheet style pivot table.
#   Supports data aggregation.
#
# ### 1. Pivot() method

# %%
import pandas as pd

# %%
# Read and show dataset
df_gdp = pd.read_excel(r'D:\Python\Data Science\Data Sets\Python for excel users\gdp.xlsx')
df_gdp
# Out:
#        unid wbid      country    year        SES       gdppc  yrseduc  \
# 0       4.0  AFG  Afghanistan  1970.0   3.474212   709.00000      NaN
# 1       4.0  AFG  Afghanistan  1920.0  26.968016   731.75677      NaN
# 2       4.0  AFG  Afghanistan  1990.0   1.269530   604.00000      NaN
# 3       4.0  AFG  Afghanistan  1960.0  15.763076   739.00000      NaN
# 4       4.0  AFG  Afghanistan  2000.0   2.061114   565.00000      NaN
# ...     ...  ...          ...     ...        ...         ...      ...
# 2081  716.0  ZWE     Zimbabwe  1940.0  52.746567   813.00000      NaN
# 2082  716.0  ZWE     Zimbabwe  2010.0  27.091389  1388.97300      NaN
# 2083  716.0  ZWE     Zimbabwe  1990.0  59.110970  2526.07230      NaN
# 2084  716.0  ZWE     Zimbabwe  1900.0  54.722645   601.00000      NaN
# 2085  716.0  ZWE     Zimbabwe  1960.0  53.811077   938.00000      NaN
#
#       popshare
# 0     0.003097
# 1     0.003245
# 2     0.002347
# 3     0.003039
# 4     0.003309
# ...        ...
# ...

# %%
# Reshape data with .pivot

df_gdp.pivot(index = 'year', columns='country', values = 'gdppc')
# Out:
# country  Afghanistan     Albania      Algeria      Angola  Argentina  \
# year
# 1880.0     585.46509   522.00000    819.18604   533.66669   1731.500
# 1890.0     635.93024   598.00000    923.37207   567.33331   2152.000
# 1900.0     686.39532   685.00000   1027.55810   601.00000   2756.000
# 1910.0     736.86047   780.00000   1131.74410   628.69232   3822.000
# 1920.0     731.75677   861.31250   1201.21620   682.62964   3473.000
# 1930.0     702.83783   929.57141   1255.81080   747.81482   4080.000
# 1940.0     673.91895   965.28571   1310.40540   813.00000   4161.000
# 1950.0     645.00000  1001.00000   1365.00000  1052.00000   4987.000
# 1960.0     739.00000  1451.00000   2088.00000  1253.00000   5559.000
# 1970.0     709.00000  2004.00000   2249.00000  1768.00000   7302.000
# 1980.0     690.00000  2347.00000   3152.00000   961.00000   8206.000
# 1990.0     604.00000  4557.40820  10238.88400  4806.43020  10833.503
# ...

# %% [markdown]
# ### 2. pivot_tables()method

# %%
# Read and show dataset

df_sales = pd.read_excel(r'D:\Python\Data Science\Data Sets\Python for excel users\supermarket_sales.xlsx')
df_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# How many females and males spend their money in this supermarket?

# Make a pivot table and add an aggregate function

df_sales.pivot_table(index = 'Gender', aggfunc = 'sum')
# Out:
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476

# %%
# Produce the above pivot table but only with quantity and totals columns

df_sales.pivot_table(index = 'Gender',
                     values = ['Quantity', 'Total'],
                     aggfunc = 'sum')
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %%
# Create a pivot table showing houch much male and female spend on each product line

df_sales.pivot_table(index = 'Gender',
                     columns = 'Product line',
                     values = 'Total',
                     aggfunc = 'sum').round(2)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                      27102.02              30437.4            33170.92
# Male                        27235.51              23868.5            22973.93
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                 18560.99            30036.88           28574.72
# Male                   30632.75            23825.04           26548.11

# %% [markdown]
# # Data Visualization with Pandas

# %%
# Read and show dataset
df_population_raw = pd.read_excel(r'D:\Python\Data Science\Data Sets\Python for excel users\population_total.xlsx')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %% [markdown]
# # 1. Making a pivot table
# .pivot() returns reshaped DataFrame organized by index, column, values without aggregation.
# ### Cleaning the DataFrame

# %%
# Dropping null values using the .dropna() function

df_population_raw.dropna(inplace=True)

# %%
# Create a pivot table using .pivot() to reshape the data.

df_pivot = df_population_raw.pivot(index= 'year', columns='country', values='population')
df_pivot
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
# Select some countries
df_pivot = df_pivot[['United States', 'India', 'China', 'Indonesia', 'Brazil']]

# %%
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# ...

# %% [markdown]
# # Visualisations.
# ### 1. Line plot
#
# ##### Note that we import matplotlib which we use for saving and exporting the pivot table and plots we will make.

# %%
import matplotlib.pyplot as plt

# %%
df_pivot.plot(kind='line', xlabel='Year',
              ylabel = 'Population', 
              title = 'Population (1955-2020)',
             figsize = (8,4))
# Save plot
plt.savefig('my_test.png')

#Show plot
plt.show()

# %% [markdown]
# ### 2. Bar plot

# %% [markdown]
# #### 2.1 Single bar plot

# %%
# Select 1 year

df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]

# Show new DataFrame

df_pivot_2020
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %% [markdown]
# ##### When we make a bar plot, we have to put text data i the index.

# %%
# Transpose DataFrame from rows to columns and viceversa.

df_pivot_2020 = df_pivot_2020.T  # df_pivot_2020.transpose() works the same.

# %%
df_pivot_2020
# Out:
# year                 2020.0
# country
# United States  3.310027e+08
# India          1.380004e+09
# China          1.439324e+09
# Indonesia      2.735236e+08
# Brazil         2.125594e+08

# %%
df_pivot_2020.plot(kind='bar', xlabel = 'Country', 
                   ylabel = 'Population',
                   title = 'Population(2020)', 
                   color = 'orange')

# Save plot
plt.savefig('Population in 2020.png')

#Show plot
plt.show()

# %% [markdown]
# #### 2.2 Bar plots grouped by 'n' variables.

# %%
df_pivot #Show pivot table
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# ...

# %%
#Select multiple years from DataFrame

    
df_pivot_sample = df_pivot[df_pivot.index.isin([1980, 1990, 2000, 2010, 2020])]
df_pivot_sample
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2010.0     309011475.0  1.234281e+09  1.368811e+09  241834215.0  195713635.0
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %%
# Transpose pivot table so rows become columns and viceversa.
# This puts the countriesin the x-axis where you can see growth per country.
# Check the last bar the following 2 bar plots and see the difference.
a = df_pivot_sample.T
a
# Out:
# year                 1980.0        1990.0        2000.0        2010.0  \
# country
# United States  2.294764e+08  2.521203e+08  2.817109e+08  3.090115e+08
# India          6.989528e+08  8.732778e+08  1.056576e+09  1.234281e+09
# China          1.000089e+09  1.176884e+09  1.290551e+09  1.368811e+09
# Indonesia      1.474478e+08  1.814134e+08  2.115138e+08  2.418342e+08
# Brazil         1.206940e+08  1.490032e+08  1.747903e+08  1.957136e+08
#
# year                 2020.0
# country
# United States  3.310027e+08
# India          1.380004e+09
# China          1.439324e+09
# Indonesia      2.735236e+08
# Brazil         2.125594e+08

# %%
df_pivot_sample.plot(kind = 'bar', xlabel = 'Year', 
                   ylabel = 'Population',
                   title = 'Population(1980, 1990, 2000, 2010, 2020)')

# Save plot
plt.savefig('Population 1980, 1990, 2000, 2010, 2020.png')

#Show plot
plt.show()

# %%
a.plot(kind='bar', xlabel = 'Country', 
       ylabel = 'Population',
       title = 'Population(1980, 1990, 2000, 2010, 2020)')
# Out:
# <AxesSubplot:title={'center':'Population(1980, 1990, 2000, 2010, 2020)'}, xlabel='Country', ylabel='Population'>

# %% [markdown]
# ### 3. Pie Chart

# %%
# Show pivot table

df_pivot_2020
# Out:
# year                 2020.0
# country
# United States  3.310027e+08
# India          1.380004e+09
# China          1.439324e+09
# Indonesia      2.735236e+08
# Brazil         2.125594e+08

# %%
# Modify the column name to be population.

df_pivot_2020.rename(columns = {2020.0:'2020'}, inplace = True)

# %%
df_pivot_2020
# Out:
# year                   2020
# country
# United States  3.310027e+08
# India          1.380004e+09
# China          1.439324e+09
# Indonesia      2.735236e+08
# Brazil         2.125594e+08

# %%
# Note that pie chart takes two arguments as a must: kind and y.
# y is the column where the data is coming from.

df_pivot_2020.plot(kind= 'pie', y = '2020', title = 'Population(2020)')

# Save plot
plt.savefig('Piechart Population in 2020.png')

#Show plot
plt.show()

# %% [markdown]
# ### Exporting the pivot table

# %%
df_pivot.to_excel('Pivot Table.xlsx')
